# %% [markdown]
# ---
# layout: post
# codemirror: true
# title: Peppa Pig Boss Battle
# description: Play the Peppa Pig Fight Club game using the notebook game runner system.
# permalink: /peppa-pig-runner/
# hide: true
# toc: false
# author: Aadi Saini
# ---

# %% [markdown]
# ## Peppa Pig Boss Battle Runner
#
# Click play in the game page and load this notebook to run the game directly in the notebook runner.

# %%
# %%js
#
# // GAME_RUNNER: Peppa Pig Boss Battle + Music API | hide_edit: true, width: 100%, height: 600px
#
# import GameControl from '@assets/js/GameEnginev1.1/essentials/GameControl.js';
#
# import PeppaWelcomeScreen from '@assets/js/projects/peppa-pig/levels/PeppaWelcomeScreen.js';
# import PeppaLevel1 from '@assets/js/projects/peppa-pig/levels/PeppaLevel1.js';
# import PeppaLevel2 from '@assets/js/projects/peppa-pig/levels/PeppaLevel2.js';
# import PeppaPowerUpMenu from '@assets/js/projects/peppa-pig/levels/PeppaPowerUpMenu.js';
# import PeppaLevel3 from '@assets/js/projects/peppa-pig/levels/PeppaLevel3.js';
# import PeppaMusic from '@assets/js/projects/peppa-pig/levels/PeppaMusic.js';
#
# const peppaMusicApi = new PeppaMusic();
# peppaMusicApi.addGestureListeners();
#
# export const gameLevelClasses = [PeppaWelcomeScreen, PeppaLevel1, PeppaLevel2, PeppaPowerUpMenu, PeppaLevel3];
# export { GameControl };
